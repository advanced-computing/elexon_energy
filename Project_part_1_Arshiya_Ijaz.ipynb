# %% [markdown]
# ## Project Part 1

# %% [markdown]
# ###Team members:
# Arshiya Sawhney: as5476
#
# Ijaz Ahmed Khan: ik2557

# %%
import pandas as pd
import requests

# %% [markdown]
# First, trying to load in dataset using the API

# %%
api_url = "https://data.elexon.co.uk/bmrs/api/v1/generation/actual/per-type?from=2024-01-01&to=2025-01-01&settlementPeriodFrom=1&settlementPeriodTo=48&format=json"

# %%
generation_by_fuel = requests.get(api_url)
generation_by_fuel.text
generation_json = generation_by_fuel.json()
generation_data = generation_json['data']

# %%
generation_data[0]
# Out:
# {'startTime': '2024-01-01T00:00:00Z',
#  'settlementPeriod': 1,
#  'data': [{'businessType': 'Solar generation',
#    'psrType': 'Solar',
#    'quantity': 352},
#   {'businessType': 'Wind generation',
#    'psrType': 'Wind Offshore',
#    'quantity': 8032},
#   {'businessType': 'Wind generation',
#    'psrType': 'Wind Onshore',
#    'quantity': 4278},
#   {'businessType': 'Production', 'psrType': 'Other', 'quantity': 327},
#   {'businessType': 'Production', 'psrType': 'Nuclear', 'quantity': 4668},
#   {'businessType': 'Production', 'psrType': 'Fossil Oil', 'quantity': 0},
#   {'businessType': 'Production', 'psrType': 'Fossil Gas', 'quantity': 4413},
#   {'businessType': 'Production',
#    'psrType': 'Fossil Hard coal',
#    'quantity': 100},
#   {'businessType': 'Production',
#    'psrType': 'Hydro Run-of-river and poundage',
#    'quantity': 673},
#   {'businessType': 'Production',
#    'psrType': 'Hydro Pumped Storage',
#    'quantity': 268},
# ...

# %%
pd.json_normalize(generation_data)
# Out:
#                 startTime  settlementPeriod  \
# 0    2024-01-01T00:00:00Z                 1
# 1    2024-01-02T00:00:00Z                 1
# 2    2024-01-03T00:00:00Z                 1
# 3    2024-01-04T00:00:00Z                 1
# 4    2024-01-05T00:00:00Z                 1
# ..                    ...               ...
# 362  2024-12-28T00:00:00Z                 1
# 363  2024-12-29T00:00:00Z                 1
# 364  2024-12-30T00:00:00Z                 1
# 365  2024-12-31T00:00:00Z                 1
# 366  2025-01-01T00:00:00Z                 1
#
#                                                   data
# 0    [{'businessType': 'Solar generation', 'psrType...
# 1    [{'businessType': 'Solar generation', 'psrType...
# 2    [{'businessType': 'Solar generation', 'psrType...
# 3    [{'businessType': 'Solar generation', 'psrType...
# 4    [{'businessType': 'Solar generation', 'psrType...
# ..                                                 ...
# ...

# %%
df1 = pd.DataFrame(generation_data)
df1.head()
## need to check how to clean the dataset
# Out:
#               startTime  settlementPeriod  \
# 0  2024-01-01T00:00:00Z                 1
# 1  2024-01-02T00:00:00Z                 1
# 2  2024-01-03T00:00:00Z                 1
# 3  2024-01-04T00:00:00Z                 1
# 4  2024-01-05T00:00:00Z                 1
#
#                                                 data
# 0  [{'businessType': 'Solar generation', 'psrType...
# 1  [{'businessType': 'Solar generation', 'psrType...
# 2  [{'businessType': 'Solar generation', 'psrType...
# 3  [{'businessType': 'Solar generation', 'psrType...
# 4  [{'businessType': 'Solar generation', 'psrType...

# %% [markdown]
# Since we are currently running into issues with the API, we have loaded in the dataset in as a csv for now.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-08c66d8b-5d23-496a-b2ac-490832ddd1c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08c66d8b-5d23-496a-b2ac-490832ddd1c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("bac410d3-8a3e-4c8d-9aad-617038c2e8f6.csv")
data.head()
# Out:
#   Dataset           PublishTime             StartTime SettlementDate  \
# 0  FUELHH  2025-02-06T05:30:00Z  2025-02-06T05:00:00Z     2025-02-06
# 1  FUELHH  2025-02-06T05:30:00Z  2025-02-06T05:00:00Z     2025-02-06
# 2  FUELHH  2025-02-06T05:30:00Z  2025-02-06T05:00:00Z     2025-02-06
# 3  FUELHH  2025-02-06T05:30:00Z  2025-02-06T05:00:00Z     2025-02-06
# 4  FUELHH  2025-02-06T05:30:00Z  2025-02-06T05:00:00Z     2025-02-06
#
#    SettlementPeriod FuelType  Generation
# 0                11  BIOMASS        3044
# 1                11     CCGT       16799
# 2                11     COAL           0
# 3                11  INTELEC        -302
# 4                11    INTEW         -26
